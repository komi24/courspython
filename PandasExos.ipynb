# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("titanic-train.csv")
print(len(df))
#print(df[~np.isnan(df["Age"])]["Age"])
plt.figure(); df.plot();
# Out:
# 891

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=range(1000), columns=list('ABCD'))
df = df.cumsum()
plt.figure(); df.plot();
plt.show()
